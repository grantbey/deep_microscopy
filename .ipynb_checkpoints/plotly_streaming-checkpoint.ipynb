# %%
import plotly.tools as tls
import numpy as np

# %%
run = np.load('./data/misc/run_counter.npy')
print('This is run {}'.format(run))
url = str(np.load('./data/logs/nuclei_plotly_url_run_{}.npy'.format(run)))
print('The plotly url is: {}'.format(url))
# Out:
# This is run 24
# The plotly url is: https://plot.ly/~grant2d2/6

# %%
tls.embed(url)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~grant2d2/6.embed" height="525" width="100%"></iframe>
